# %%
import requests
import pandas as pd

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# Project Overview:-
#
# This project examines Machine Learning repositories aggregated by using GitHub.
#
# Some context on the data itself: it was collected through Github API, cleaned and prepared with Python + Pandas, analyzed with SQL and visualized in order to find any patterns or insights that could be useful.
#
# Main Tools:
# Python,
# Pandas,
# SQLite,
# SQL,
# Matplotlib,
# GitHub API.

# %% [markdown]
# 1. Data Collection
#
# In this step I retrieved from GitHub the most-starred Machine Learning repositories using the GitHub API.
#
# API response with information about the repositories in JSON format, and we will parse it into Pandas DataFrame to analyze.

# %%
url = "https://api.github.com/search/repositories"
params = {
    "q": "machine learning",
    "sort": "stars",
    "order": "desc",
    "per_page": 100
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()

    df = pd.DataFrame(data["items"])

    print("Data collected successfully!")
    print("Number of repositories:", len(df))
else:
    print("Failed to retrieve data.")
    print("Status code:", response.status_code)
# Out:
# Data collected successfully!
# Number of repositories: 100

# %%
print("Dataset shape:", df.shape)

print("\nFirst 5 repositories:")
display(df[["name", "language", "stargazers_count", "forks_count"]].head())
# Out:
# Dataset shape: (100, 82)
#
# First 5 repositories:
#                        name          language  stargazers_count  forks_count
# 0                tensorflow               C++            197328        76098
# 1              transformers            Python            164344        34327
# 2          ML-For-Beginners  Jupyter Notebook             89685        22037
# 3                    funNLP            Python             82599        15272
# 4  awesome-machine-learning            Python             74118        15618

# %%
print("Dataset shape:")
print(df.shape)
# Out:
# Dataset shape:
# (100, 82)

# %%
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# Column names:
# ['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'has_discussions', 'forks_count', 'mirror_url', 'archived', 'disabled', 'open_issues_count', 'license', 'allow_forking', 'is_template', 'web_commit_signoff_required', 'has_pull_requests', 'pull_request_creation_policy', 'topics', 'visibility', 'forks', 'open_issues', 'watchers', 'default_branch', 'score']

# %%
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# id                  int64
# node_id            object
# name               object
# full_name          object
# private              bool
#                    ...
# forks               int64
# open_issues         int64
# watchers            int64
# default_branch     object
# score             float64
# Length: 82, dtype: object

# %%
print("\nMissing values:")
print(df.isnull().sum().sort_values(ascending=False).head(20))
# Out:
# Missing values:
# mirror_url           100
# language              23
# license               22
# homepage               8
# private                0
# owner                  0
# name                   0
# full_name              0
# fork                   0
# url                    0
# forks_url              0
# keys_url               0
# collaborators_url      0
# teams_url              0
# html_url               0
# description            0
# id                     0
# node_id                0
# assignees_url          0
# events_url             0
# dtype: int64

# %%
selected_columns = [
    "name",
    "owner",
    "language",
    "stargazers_count",
    "forks_count",
    "watchers_count",
    "open_issues_count",
    "created_at",
    "updated_at",
    "license"
]

df = df[selected_columns].copy()
print("Selected columns:", len(df.columns))
print("New dataset shape:", df.shape)
display(df.head())
# Out:
# Selected columns: 10
# New dataset shape: (100, 10)
#                        name  \
# 0                tensorflow
# 1              transformers
# 2          ML-For-Beginners
# 3                    funNLP
# 4  awesome-machine-learning
#
#                                                owner          language  \
# 0  {'login': 'tensorflow', 'id': 15658638, 'node_...               C++
# 1  {'login': 'huggingface', 'id': 25720743, 'node...            Python
# 2  {'login': 'microsoft', 'id': 6154722, 'node_id...  Jupyter Notebook
# 3  {'login': 'fighting41love', 'id': 11475294, 'n...            Python
# 4  {'login': 'josephmisiti', 'id': 246302, 'node_...            Python
#
#    stargazers_count  forks_count  watchers_count  open_issues_count  \
# 0            197328        76098          197328               2933
# 1            164344        34327          164344               2397
# 2             89685        22037           89685                 13
# 3             82599        15272           82599                 52
# 4             74118        15618           74118                 26
#
#              created_at            updated_at  \
# 0  2015-11-07T01:19:20Z  2026-08-22T20:02:17Z
# 1  2018-10-29T13:56:00Z  2026-08-22T20:27:49Z
# 2  2021-03-03T01:34:05Z  2026-08-22T20:03:47Z
# 3  2018-08-21T11:20:39Z  2026-08-22T17:48:46Z
# 4  2014-07-15T19:11:19Z  2026-08-22T19:52:07Z
#
#                                              license
# 0  {'key': 'apache-2.0', 'name': 'Apache License ...
# 1  {'key': 'apache-2.0', 'name': 'Apache License ...
# 2  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 3                                               None
# 4  {'key': 'other', 'name': 'Other', 'spdx_id': '...

# %%
df["owner"] = df["owner"].apply(
    lambda owner: owner["login"] if isinstance(owner, dict) else owner
)

df["license"] = df["license"].apply(
    lambda license_info: license_info["spdx_id"]
    if isinstance(license_info, dict)
    else license_info
)

print("Owner and license values extracted successfully!")

print("\nSample data:")
display(df[["name", "owner", "license"]].head())
# Out:
# Owner and license values extracted successfully!
#
# Sample data:
#                        name           owner      license
# 0                tensorflow      tensorflow   Apache-2.0
# 1              transformers     huggingface   Apache-2.0
# 2          ML-For-Beginners       microsoft          MIT
# 3                    funNLP  fighting41love         None
# 4  awesome-machine-learning    josephmisiti  NOASSERTION

# %%
print("Missing values before cleaning:")
print(df.isnull().sum())
# Out:
# Missing values before cleaning:
# name                  0
# owner                 0
# language             23
# stargazers_count      0
# forks_count           0
# watchers_count        0
# open_issues_count     0
# created_at            0
# updated_at            0
# license              22
# dtype: int64

# %%
df["language"] = df["language"].fillna("Not specified")

df["license"] = df["license"].fillna("No license")
print("Missing values handled successfully!")

print("\nMissing values after cleaning:")
print(df.isnull().sum())
# Out:
# Missing values handled successfully!
#
# Missing values after cleaning:
# name                 0
# owner                0
# language             0
# stargazers_count     0
# forks_count          0
# watchers_count       0
# open_issues_count    0
# created_at           0
# updated_at           0
# license              0
# dtype: int64

# %%
duplicates = df.duplicated(subset="name").sum()
print("Duplicate repositories:", duplicates)
# Out:
# Duplicate repositories: 1

# %%
df = df.drop_duplicates(subset=["owner", "name"])
print("Shape after removing duplicates:", df.shape)
# Out:
# Shape after removing duplicates: (100, 10)

# %%
print("\nDuplicates after cleaning:")
print(df.duplicated(subset=["owner", "name"]).sum())
# Out:
# Duplicates after cleaning:
# 0

# %%
df["created_at"] = pd.to_datetime(df["created_at"], errors="coerce")
df["updated_at"] = pd.to_datetime(df["updated_at"], errors="coerce")

# %%
df = df.rename(columns={
    "stargazers_count": "stars",
    "forks_count": "forks",
    "watchers_count": "watchers",
    "open_issues_count": "open_issues",
    "created_at": "created_date",
    "updated_at": "updated_date"
})

print("Dataset prepared successfully!")
# Out:
# Dataset prepared successfully!

# %%
print("\nFinal columns:")
print(df.columns.tolist())
# Out:
# Final columns:
# ['name', 'owner', 'language', 'stars', 'forks', 'watchers', 'open_issues', 'created_date', 'updated_date', 'license']

# %%
df.to_csv("github_projects.csv", index=False)
print("Final dataset saved as github_projects.csv")
# Out:
# Final dataset saved as github_projects.csv

# %%
final_df = pd.read_csv("github_projects.csv")
print("Saved dataset loaded successfully!")
print("Dataset shape:", final_df.shape)
# Out:
# Saved dataset loaded successfully!
# Dataset shape: (100, 10)

# %%
print("\nFinal columns:")
print(final_df.columns.tolist())
# Out:
# Final columns:
# ['name', 'owner', 'language', 'stars', 'forks', 'watchers', 'open_issues', 'created_date', 'updated_date', 'license']

# %% [markdown]
# **Task 2 – Store and Analyse the Data**
#
# *Step 1: Create the SQLite Database*

# %%
import sqlite3
import pandas as pd

# %%
df = pd.read_csv("github_projects.csv")
print("Cleaned dataset loaded successfully!")
print("Rows:", len(df))
# Out:
# Cleaned dataset loaded successfully!
# Rows: 100

# %%
connection = sqlite3.connect("github_projects.db")
print("Database created successfully!")
# Out:
# Database created successfully!

# %%
df.to_sql("Repositories", connection,if_exists="replace", index=False)
print("Table 'Repositories' created successfully.")
# Out:
# Table 'Repositories' created successfully.

# %%
result = pd.read_sql_query("SELECT COUNT(*) AS total_repositories FROM Repositories",connection)
print(result)
# Out:
#    total_repositories
# 0                 100

# %%
query = """
SELECT name, language, stars
FROM Repositories
WHERE stars > 10000
ORDER BY stars DESC
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#                                name          language   stars
# 0                        tensorflow               C++  197328
# 1                      transformers            Python  164344
# 2                  ML-For-Beginners  Jupyter Notebook   89685
# 3                            funNLP            Python   82599
# 4          awesome-machine-learning            Python   74118
# ..                              ...               ...     ...
# 65  machine-learning-systems-design              HTML   10538
# 66                 Machine-Learning            Python   10372
# 67           machine-learning-notes  Jupyter Notebook   10337
# 68              3D-Machine-Learning     Not specified   10191
# 69                             tpot  Jupyter Notebook   10052
#
# [70 rows x 3 columns]

# %%
query = """
SELECT name, language, stars
FROM Repositories
WHERE name LIKE '%Machine%'
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#                                                  name          language  stars
# 0                            awesome-machine-learning            Python  74118
# 1   500-AI-Machine-learning-Deep-learning-Computer...     Not specified  36454
# 2             machine-learning-for-software-engineers     Not specified  28867
# 3                           homemade-machine-learning  Jupyter Notebook  24773
# 4                 awesome-production-machine-learning     Not specified  20861
# 5                        machine-learning-for-trading  Jupyter Notebook  20578
# 6                    stanford-cs-229-machine-learning     Not specified  20142
# 7                          Machine-Learning-Tutorials     Not specified  18133
# 8                           machine-learning-zoomcamp  Jupyter Notebook  13987
# 9                          machine-learning-interview     Not specified  12789
# 10                       python-machine-learning-book  Jupyter Notebook  12640
# 11                         dive-into-machine-learning     Not specified  11390
# 12                    machine-learning-systems-design              HTML  10538
# 13                                   Machine-Learning            Python  10372
# 14                             machine-learning-notes  Jupyter Notebook  10337
# 15                                3D-Machine-Learning     Not specified  10191
# 16                                    machinelearning                C#   9350
# 17                          machine_learning_examples            Python   8911
# 18  state-of-the-art-result-for-machine-learning-p...     Not specified   8894
# 19                         financial-machine-learning            Python   8755
# 20                                    machinelearning  Jupyter Notebook   8706
# 21                             MachineLearning_Python            Python   8581
# 22                        Machine-Learning-Collection            Python   8489
# 23                       machine-learning-cheat-sheet               TeX   8043
# 24                           machine-learning-roadmap     Not specified   7893
# 25                       machine-learning-yearning-cn               CSS   7844
# 26           Machine-Learning-Specialization-Coursera  Jupyter Notebook   7799
# 27                    Machine-learning-learning-notes     Not specified   7761
# 28                 Learn_Machine_Learning_in_3_Months     Not specified   7603
# 29                          industry-machine-learning  Jupyter Notebook   7483

# %%
query = """
SELECT name, language, stars, forks
FROM Repositories
WHERE stars > 10000
AND forks > 5000
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#                                                  name          language  \
# 0                                          tensorflow               C++
# 1                                        transformers            Python
# 2                                    ML-For-Beginners  Jupyter Notebook
# 3                                              funNLP            Python
# 4                            awesome-machine-learning            Python
# 5                                        scikit-learn            Python
# 6   500-AI-Machine-learning-Deep-learning-Computer...     Not specified
# 7                                         C-Plus-Plus               C++
# 8                                     ML-From-Scratch            Python
# 9             machine-learning-for-software-engineers     Not specified
# 10                 linkedin-skill-assessments-quizzes            Python
# 11                                             Paddle               C++
# 12                       machine-learning-for-trading  Jupyter Notebook
# 13                                                ivy            Python
# 14                                        handson-ml3  Jupyter Notebook
# 15                          amazon-sagemaker-examples  Jupyter Notebook
# 16                                        mlcourse.ai            Python
# 17                                   Machine-Learning            Python
#
#      stars  forks
# 0   197328  76098
# 1   164344  34327
# 2    89685  22037
# 3    82599  15272
# 4    74118  15618
# 5    67010  27299
# 6    36454   7454
# 7    34591   7850
# 8    32507   5431
# 9    28867   6146
# 10   28804  12906
# 11   24061   6015
# 12   20578   5551
# 13   14172   5460
# 14   13972   5260
# 15   10979   6961
# 16   10692   5697
# 17   10372   5065

# %%
query = """
SELECT name, language, stars
FROM Repositories
WHERE language = 'Python'
OR language = 'C++'
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#                                   name language   stars
# 0                           tensorflow      C++  197328
# 1                         transformers   Python  164344
# 2                               funNLP   Python   82599
# 3             awesome-machine-learning   Python   74118
# 4                         scikit-learn   Python   67010
# 5                               gradio   Python   43405
# 6                          C-Plus-Plus      C++   34591
# 7                      ML-From-Scratch   Python   32507
# 8   linkedin-skill-assessments-quizzes   Python   28804
# 9                          cs249r_book   Python   27979
# 10                              Paddle      C++   24061
# 11                                onnx   Python   21348
# 12                                rasa   Python   21302
# 13                             video2x      C++   21020
# 14                            LightGBM      C++   18707
# 15                      ml-engineering   Python   18687
# 16                                brpc      C++   17592
# 17                            numpy-ml   Python   16333
# 18                                ggml      C++   15217
# 19                              imgaug   Python   14739
# 20                             bullet3      C++   14685
# 21                          ChatterBot   Python   14509
# 22                                dlib      C++   14433
# 23                                 nni   Python   14363
# 24                                 ivy   Python   14172
# 25                                 tvm   Python   13676
# 26                            cleanlab   Python   11630
# 27                        MLAlgorithms   Python   11169
# 28                          turicreate      C++   11160
# 29                               dolly   Python   10804
# 30                             doccano   Python   10754
# 31                         mlcourse.ai   Python   10692
# 32                    Machine-Learning   Python   10372
# 33                              sktime   Python    9958
# 34                            catboost      C++    9073
# 35           machine_learning_examples   Python    8911
# 36                             pattern   Python    8861
# 37          financial-machine-learning   Python    8755
# 38                       vowpal_wabbit      C++    8705
# 39              MachineLearning_Python   Python    8581
# 40         Machine-Learning-Collection   Python    8489
# 41                        auto-sklearn   Python    8126

# %%
query = """
SELECT name, language, stars
FROM Repositories
WHERE NOT language = 'Python'
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#                                                  name          language  \
# 0                                          tensorflow               C++
# 1                                    ML-For-Beginners  Jupyter Notebook
# 2   500-AI-Machine-learning-Deep-learning-Computer...     Not specified
# 3                                         C-Plus-Plus               C++
# 4                                              netron        JavaScript
# ..                                                ...               ...
# 65                    Machine-learning-learning-notes     Not specified
# 66                                  awesome-youtubers          Markdown
# 67                 Learn_Machine_Learning_in_3_Months     Not specified
# 68                                              h2o-3  Jupyter Notebook
# 69                          industry-machine-learning  Jupyter Notebook
#
#      stars
# 0   197328
# 1    89685
# 2    36454
# 3    34591
# 4    33387
# ..     ...
# 65    7761
# 66    7740
# 67    7603
# 68    7495
# 69    7483
#
# [70 rows x 3 columns]

# %%
query = """
SELECT name, language, stars
FROM Repositories
ORDER BY stars DESC
LIMIT 10
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#                                                 name          language   stars
# 0                                         tensorflow               C++  197328
# 1                                       transformers            Python  164344
# 2                                   ML-For-Beginners  Jupyter Notebook   89685
# 3                                             funNLP            Python   82599
# 4                           awesome-machine-learning            Python   74118
# 5                                       scikit-learn            Python   67010
# 6                                             gradio            Python   43405
# 7  500-AI-Machine-learning-Deep-learning-Computer...     Not specified   36454
# 8                                        C-Plus-Plus               C++   34591
# 9                                             netron        JavaScript   33387

# %%
query = """
SELECT COUNT(*) AS total_repositories
FROM Repositories
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#    total_repositories
# 0                 100

# %%
query = """
SELECT AVG(stars) AS average_stars
FROM Repositories
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#    average_stars
# 0       20822.08

# %%
query = """
SELECT language, COUNT(*) AS repository_count
FROM Repositories
GROUP BY language
HAVING COUNT(*) > 5
ORDER BY repository_count DESC
"""
result = pd.read_sql_query(query, connection)
print(result)
# Out:
#            language  repository_count
# 0            Python                30
# 1     Not specified                23
# 2  Jupyter Notebook                19
# 3               C++                12

# %%
import matplotlib.pyplot as plt
query = """
SELECT name, stars
FROM Repositories
ORDER BY stars DESC
LIMIT 10
"""
top_repositories = pd.read_sql_query(query, connection)
plt.figure(figsize=(10, 6))
plt.barh(top_repositories["name"][::-1], top_repositories["stars"][::-1])
plt.xlabel("Stars")
plt.ylabel("Repository")
plt.title("Top 10 Repositories by Stars")
plt.tight_layout()
plt.show()

# %%
query = """
SELECT
    strftime('%Y', created_date) AS year,
    COUNT(*) AS repository_count
FROM Repositories
GROUP BY year
ORDER BY year
"""
creation_trend = pd.read_sql_query(query, connection)
print(creation_trend)
# Out:
#     year  repository_count
# 0   2009                 1
# 1   2010                 2
# 2   2011                 2
# 3   2013                 3
# 4   2014                 6
# 5   2015                 7
# 6   2016                14
# 7   2017                17
# 8   2018                18
# 9   2019                 7
# 10  2020                10
# 11  2021                 6
# 12  2022                 3
# 13  2023                 3
# 14  2024                 1

# %%
plt.figure(figsize=(10, 5))
plt.plot(creation_trend["year"], creation_trend["repository_count"],marker="o")
plt.xlabel("Year")
plt.ylabel("Number of Repositories")
plt.title("Repositories Created Over Time")
plt.tight_layout()
plt.show()

# %% [markdown]
#  ***Step 8 – Interpretation of the Results***
#
# From the analysis, it is evident that Python is the most widely used programming language within the repositories with 30 repositories using Python. There were some repositories that had no language defined, while Jupyter Notebook and C++ were other widely used languages.
#
# The analysis reveals that there has been an increase in repository creation from one year to another and that the highest point was achieved in 2018 where there were 18 repositories created. After 2018, the number has generally gone down.
#
# There is a very high positive correlation between stars and forks. It is clear that popular repositories with many stars also get many forks.
#
# In conclusion, from the analysis of the results, it can be seen that machine learning repositories in the dataset are mostly related to Python programming language.

# %% [markdown]
# #Task 3: Step 7:-
# **1. Why is it important to verify data collected from public APIs?**
#
# It is important to check the accuracy of the data obtained from public APIs because the data might include missing or inaccurate entries. Since in this project, the repository data was collected from the GitHub API, the data set had to be checked to ensure that the analyzed information was accurate.
#
#  **2. Why should data analysts document the source of their data?**
#  The data analysts should document the data source because it would help trace the analysis to the origin of the data. In this project, the data was collected from the GitHub API. This fact makes it important to document the data source to make the project more transparent and understandable for other people.
#
#  **3. How can missing or inaccurate data affect data analysis and decision-making?**
#
#  Incorrect data or missing data can influence the analysis process as well as the outcome and can cause wrong decisions or wrong conclusions to be made. Missing information on programming languages in the GitHub data set, for instance, would have influenced the analysis of the most popular programming languages. Cleaning and validating the data would go a long way in minimizing such risks.
